# %%
# poc: mlrosewin@gmail.com
# file: xgboost_forecast_sunspots.ipynb
# date created: jan 2021
# last update: jan 2021

# %% [markdown]
# ### Imports

# %%
# %matplotlib inline

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Data Ingest

# %%
df = pd.read_csv('./data/data_sunspots.csv')
df.columns = ['Date', 'Sunspots']

print(df.shape)
print(df.columns)
df.head(3)
# Out:
# (3252, 2)
# Index(['Date', 'Sunspots'], dtype='object')
#          Date  Sunspots
# 0  1749-01-31      96.7
# 1  1749-02-28     104.3
# 2  1749-03-31     116.7

# %% [markdown]
# ### Basic Visualization

# %%
plt.figure(figsize=(20,8))
plt.style.use('seaborn-poster')
plt.style.use('seaborn-whitegrid')
plt.plot(df['Date'], df['Sunspots']);
plt.xlabel('Date')
plt.ylabel('Mean Monthly Observed Sunspot Number')
# Out:
# Text(0, 0.5, 'Mean Monthly Observed Sunspot Number')
